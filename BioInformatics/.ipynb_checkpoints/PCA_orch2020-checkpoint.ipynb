# %%
source("/home/users/mcbitter/OrchardProject/Code/config.R")
source("/home/users/mcbitter/OrchardProject/Code/helper_functions.R")
source("/home/users/mcbitter/OrchardProject/Code/load_packages.R")
source("/home/users/mcbitter/OrchardProject/Code/plotting_functions.R")
source("/home/users/mcbitter/OrchardProject/Code/workflow_functions.R")
source("/home/users/mcbitter/OrchardProject/Code/general_cage_functions.R")
setwd('/scratch/groups/dpetrov/MarkB/Orchard2020Data/RData/')

# %%
plot_pca_tpt = function(df, samps){
    ggplot(pca_data, aes(x = PC1, y = PC2, color = Timepoint)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        scale_color_gradient(low = "red", high = "blue") +
        theme_bw(base_size = 15) 
}

# %%
load('./orch2020.RData')

# %%
head(samps)
# Out:
#   full.sample.name Timepoint treatment cage
# 1 TP1_A_1          1         A         1
# 2 TP1_A_2          1         A         2
# 3 TP1_A_3          1         A         3
# 4 TP1_A_4          1         A         4
# 5 TP1_A_5          1         A         5
# 6 TP1_A_6          1         A         6

# %%
#PCA all samples
load('./orch2020.RData')
df = afmat
pca_res <- prcomp(na.omit(t(df)), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)


 ggplot(pca_data, aes(x = PC1, y = PC2, color = Timepoint, shape = treatment)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        scale_color_gradient(low = "red", high = "blue") +
        theme_bw(base_size = 15) 

 ggplot(pca_data, aes(x = PC1, y = PC2, color = Timepoint, shape = treatment, label = full.sample.name)) +
        geom_point(size = 5) +
        geom_text(hjust=0, vjust=0) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        scale_color_gradient(low = "red", high = "blue") +
        theme_bw(base_size = 15)

# %%
#PCA removing outlier (TP5_B_4)
df = afmat %>% dplyr::select(-'TP5_B_4')
samps = samps %>% filter(full.sample.name != 'TP5_B_4')
pca_res <- prcomp(na.omit(t(df)), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)


 ggplot(pca_data, aes(x = PC1, y = PC2, color = Timepoint, shape = treatment)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        scale_color_gradient(low = "red", high = "blue") +
        theme_bw(base_size = 15)
# Out:
# plot without title

# %%
#Just looking at bloomington vs bacterial conditioned - all tpts
load('./orch2020.RData')
df = cbind(samps, t(afmat))

df = df %>% filter(treatment != 'A')

df = df %>% rename(Timepoint = tpt)
df = df %>% filter(Timepoint %in% c('2', '4', '5'))

samps = df[,1:ncol(samps)]
df = df[, -c(1:ncol(samps))]

pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)


 ggplot(pca_data, aes(x = PC1, y = PC2, color = Timepoint, shape = treatment)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        scale_color_gradient(low = "red", high = "blue") +
        theme_bw(base_size = 15)
# Out:
#         full.sample.name tpt treatment cage 1
# TP1_B_1 TP1_B_1          1   B         1    0.372867
# TP1_B_2 TP1_B_2          1   B         2    0.286560
# TP1_B_3 TP1_B_3          1   B         3    0.321966
# TP1_B_4 TP1_B_4          1   B         4    0.371443
# TP1_B_5 TP1_B_5          1   B         5    0.312038
# TP1_B_6 TP1_B_6          1   B         6    0.302936

# %%
#Just looking at bloomington vs bacterial conditioned - all tpts
load('./orch2020.RData')
df = cbind(samps, t(afmat))

df = df %>% filter(treatment != 'B')

df = df %>% rename(Timepoint = tpt)
df = df %>% filter(Timepoint %in% c('2', '4', '5'))

samps = df[,1:ncol(samps)]
df = df[, -c(1:ncol(samps))]

pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)


 ggplot(pca_data, aes(x = PC1, y = PC2, color = Timepoint, shape = treatment)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        scale_color_gradient(low = "red", high = "blue") +
        theme_bw(base_size = 15)
# Out:
# plot without title

# %%
#Just looking at bloomington vs bacterial conditioned - tpt 2
load('./orch2020.RData')
df = cbind(samps, t(afmat))
df = df %>% filter(treatment != 'A')

df = df %>% rename(Timepoint = tpt)
df = df %>% filter(Timepoint %in% c('2'))


samps = df[,1:ncol(samps)]
df = df[, -c(1:ncol(samps))]

pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)


 ggplot(pca_data, aes(x = PC1, y = PC2, shape = treatment)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        scale_color_gradient(low = "red", high = "blue") +
        theme_bw(base_size = 15)
# Out:
# plot without title

# %%
#Just looking at bloomington vs bacterial conditioned - tpt 4
load('./orch2020.RData')
df = cbind(samps, t(afmat))
df = df %>% filter(treatment != 'A')
df = df %>% rename(Timepoint = tpt)
df = df %>% filter(Timepoint %in% c('4'))

samps = df[,1:ncol(samps)]
df = df[, -c(1:ncol(samps))]

pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)


 ggplot(pca_data, aes(x = PC1, y = PC2, shape = treatment)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        theme_bw(base_size = 15)
# Out:
# plot without title

# %%
#Just looking at bloomington vs bacterial conditioned  - tpt 5
load('./orch2020.RData')
df = cbind(samps, t(afmat))
df = df %>% filter(treatment != 'A')
df = df %>% rename(Timepoint = tpt)
df = df %>% filter(Timepoint %in% c('5'))

samps = df[,1:ncol(samps)]
df = df[, -c(1:ncol(samps))]

pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)


 ggplot(pca_data, aes(x = PC1, y = PC2, shape = treatment)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        theme_bw(base_size = 15)
# Out:
# plot without title

# %%
samps = samps %>% filter(treatment != 'A')
samps = samps %>% filter(Timepoint %in% c('2', '4', '5'))

pca_res <- prcomp(na.omit(t(df)), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)


 ggplot(pca_data, aes(x = PC1, y = PC2, color = Timepoint, shape = treatment)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        scale_color_gradient(low = "red", high = "blue") +
        theme_bw(base_size = 15)
# Out:
#   TP1_B_2   TP1_B_4   TP1_B_5   TP1_B_6   TP2_B_2   TP2_B_4   TP2_B_5
# 1 0.2865600 0.3714430 0.3120380 0.3029360 0.2618170 0.3828230 0.2494230
# 2 0.0861780 0.0757646 0.0701474 0.0677632 0.0818034 0.1276310 0.0588476
# 3 0.0336977 0.0324693 0.0201666 0.0319093 0.0246624 0.0223817 0.0185559
# 4 0.0653937 0.0574630 0.0529874 0.0444648 0.0620862 0.0898144 0.0478996
# 5 0.2710870 0.3565130 0.2970330 0.2931330 0.2486580 0.3539870 0.2335200
# 6 0.0552881 0.0844764 0.1146890 0.0868850 0.0674652 0.0996490 0.0603559
#   TP2_B_6   TP2_M_2   TP2_M_4   ⋯ TP5_B_4   TP5_B_5   TP5_B_6   TP5_M_2
# 1 0.2540540 0.3070120 0.2508500 ⋯ 0.3667610 0.3741090 0.3486300 0.2699690
# 2 0.0787321 0.0653193 0.0591777 ⋯ 0.0674538 0.1367690 0.0981098 0.0979313
# 3 0.0207316 0.0235429 0.0267598 ⋯ 0.0146634 0.0392077 0.0250763 0.0211412
# 4 0.0629992 0.0517130 0.0452971 ⋯ 0.0512016 0.1046910 0.0805850 0.0761067
# 5 0.2321950 0.2951510 0.2327210 ⋯ 0.3533420 0.3427340 0.3147030 0.2501780
# 6 0.0439675 0.0786505 0.0705663 ⋯ 0.0375016 0.0529989 0.0606621 0.0515982
#   TP5_M_4   TP5_M_5   TP5_M_6   TP5_M_7   TP5_M_8   TP5_M_9
# 1 0.2439460 0.2834460 0.2876330 0.3004270 0.4071630 0.4153750
# 2 0.0673213 0.1090850 0.0951207 0.0569195 0.1309440 0.1257180
# 3 0.0279914 0.0195230 0.0180805 0.0248730 0.0141759 0.0178859
# 4 0.0535304 0.0851303 0.0774408 0.0479622 0.1060470 0.0998234
# 5 0.2210490 0.2611230 0.2613900 0.2841200 0.3855280 0.3886240
# 6 0.0648033 0.0606398 0.0703709 0.0619567 0.0828560 0.1476960

# %%
#Just looking at Apple vs bacterial conditioned 

tps = c('2', '4', '5')
for (tp in tps){
    load('./orch2020.RData')
    df = cbind(samps, t(afmat))
    df = df %>% filter(treatment != 'B')
    df = df %>% rename(Timepoint = tpt)
    df = df %>% filter(Timepoint == tp)
    samps = df[,1:ncol(samps)]
    df = df[, -c(1:ncol(samps))]

    pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
    pca_data <- as.data.frame(pca_res$x)
    pca_data <- cbind(samps, pca_data)
    pca_data$Timepoint = as.numeric(pca_data$Timepoint)
    print(ggplot(pca_data, aes(x = PC1, y = PC2, shape = treatment)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        scale_color_gradient(low = "red", high = "blue") +
        theme_bw(base_size = 15) )


    
}
# Out:
# plot without title
# plot without title
# plot without title

# %%
#Just looking at Apple vs bacterial conditioned 

tps = c('2', '4', '5')
for (tp in tps){
    load('./orch2020.RData')
    df = cbind(samps, t(afmat))
    df = df %>% filter(treatment != 'B')
    df = df %>% rename(Timepoint = tpt)
    df = df %>% filter(Timepoint == tp)
    samps = df[,1:ncol(samps)]
    df = df[, -c(1:ncol(samps))]

    pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
    pca_data <- as.data.frame(pca_res$x)
    pca_data <- cbind(samps, pca_data)
    pca_data$Timepoint = as.numeric(pca_data$Timepoint)
    print(ggplot(pca_data, aes(x = PC1, y = PC2, colour = treatment, shape = treatment)) +
        geom_point(size = 5) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        theme_bw(base_size = 15) )


    
}
# Out:
# plot without title
# plot without title
# plot without title

# %%
load('./orch2020.RData')
df = cbind(samps, t(afmat))
df = df %>% filter(treatment == 'M')
df = df %>% rename(Timepoint = tpt)
samps = df[,1:ncol(samps)]
df = df[, -c(1:ncol(samps))]

pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
 pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)
ggplot(pca_data, aes(x = PC1, y = PC2, colour = Timepoint,label = full.sample.name)) +
        geom_point(size = 5) +
        geom_text(hjust=0, vjust=0) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        scale_color_gradient(low = "red", high = "blue") +
        theme_bw(base_size = 15)
# Out:
# plot without title

# %%
load('./orch2020.RData')
df = cbind(samps, t(afmat))
df = df %>% rename(Timepoint = tpt)
df = df %>% filter(treatment == 'M' & Timepoint == '2')
samps = df[,1:ncol(samps)]
df = df[, -c(1:ncol(samps))]

pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
 pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)
ggplot(pca_data, aes(x = PC1, y = PC2, label = full.sample.name)) +
        geom_point(size = 5) +
        geom_text(hjust=0, vjust=0) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        theme_bw(base_size = 15)
# Out:
# plot without title

# %%
load('./orch2020.RData')
df = cbind(samps, t(afmat))
df = df %>% rename(Timepoint = tpt)
df = df %>% filter(treatment == 'M' & Timepoint == '4')
samps = df[,1:ncol(samps)]
df = df[, -c(1:ncol(samps))]

pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
 pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)
ggplot(pca_data, aes(x = PC1, y = PC2, label = full.sample.name)) +
        geom_point(size = 5) +
        geom_text(hjust=0, vjust=0) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        theme_bw(base_size = 15)
# Out:
# plot without title

# %%
load('./orch2020.RData')
df = cbind(samps, t(afmat))
df = df %>% rename(Timepoint = tpt)
df = df %>% filter(treatment == 'M' & Timepoint == '5')
samps = df[,1:ncol(samps)]
df = df[, -c(1:ncol(samps))]

pca_res <- prcomp(na.omit(df), scale = TRUE, center = TRUE)
pca_data <- as.data.frame(pca_res$x)
 pca_data <- cbind(samps, pca_data)
pca_data$Timepoint = as.numeric(pca_data$Timepoint)
ggplot(pca_data, aes(x = PC1, y = PC2, label = full.sample.name)) +
        geom_point(size = 5) +
        geom_text(hjust=0, vjust=0) +
        xlab(paste0("PC1 (", round(summary(pca_res)$importance[2,1] * 100, 2), " % expl. var.)")) +
        ylab(paste0("PC2 (", round(summary(pca_res)$importance[2,2] * 100, 2), " % expl. var.)")) +
        theme_bw(base_size = 15)
# Out:
# plot without title
